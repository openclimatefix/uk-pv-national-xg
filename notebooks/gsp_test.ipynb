# %%
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt

# %%
# test access to GSP PV data from GCP
fpath = "gs://solar-pv-nowcasting-data/PV/GSP/v5/pv_gsp.zarr"
gsp = xr.open_zarr(fpath)

# %%
gsp
# Out:
# <xarray.Dataset>
# Dimensions:                (datetime_gmt: 150865, gsp_id: 318)
# Coordinates:
#   * datetime_gmt           (datetime_gmt) datetime64[ns] 2014-01-01 ... 2022-...
#   * gsp_id                 (gsp_id) int64 0 1 2 3 4 5 ... 313 314 315 316 317
# Data variables:
#     generation_mw          (datetime_gmt, gsp_id) float64 ...
#     installedcapacity_mwp  (datetime_gmt, gsp_id) float64 ...

# %%
X = gsp.isel(datetime_gmt=0, gsp_id=0).to_array()

# %%
X
# Out:
# <xarray.DataArray (variable: 2)>
# array([   0.    , 2909.3509])
# Coordinates:
#     datetime_gmt  datetime64[ns] 2014-01-01
#     gsp_id        int64 0
#   * variable      (variable) object 'generation_mw' 'installedcapacity_mwp'

# %%
X.values
# Out:
# array([   0.    , 2909.3509])
