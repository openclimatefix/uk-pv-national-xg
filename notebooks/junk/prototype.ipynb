# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import datetime as dt
import pandas as pd

# %%
nwp_path = "gs://solar-pv-nowcasting-data/NWP/UK_Met_Office/UKV_intermediate_version_3.zarr/"
gsp_path = "gs://solar-pv-nowcasting-data/PV/GSP/v5/pv_gsp.zarr"
gsp = xr.open_zarr(gsp_path)
nwp = xr.open_zarr(nwp_path)

# %%
def build_datasets_for_prediction_horizon(hour_forecast_horizon: int):
    # select the nwp variables at the prediction horizon
    X = nwp.isel(step=hour_forecast_horizon)
    
    # select the relevant PV target - shift by the prediction horizon
    target = gsp["generation_mw"].where((gsp["datetime_gmt"] >= X.coords["init_time"].values[0] + X.step.values) & (gsp["datetime_gmt"] <= X.coords["init_time"].values[-1] + X.step.values), drop=True)
    target = target.isel(gsp_id=0) 
    
    X = X.chunk({"init_time": 1, "variable": 1})
    # take geospatial mean
    X = X.mean(dim=["x", "y"])
    # interpolate to 1/2 hourly (same resolution as PV target)
    new_times = target.coords["datetime_gmt"].values - X.step.values
    X = X.interp(init_time=new_times, method="cubic")
    
    # compute the transformation - this can take some time
    _X = X.to_array().as_numpy()
    _X = _X.values.reshape(_X.shape[1], _X.shape[2]).T
    
    # compute datetime features
    datetime_features = trigonometric_datetime_transformation(X["init_time"])
    
    # concat
    _X = np.concatenate((_X, datetime_features), axis=1)
    
    return _X, target

# stolen from datapipes

from pandas.core.dtypes.common import is_datetime64_dtype
import numpy.typing as npt
from typing import Union, Tuple

def _trig_transform(values: np.ndarray, period: Union[float, int]) -> Tuple[np.ndarray, np.ndarray]:
    """
    Given a list of values and an upper limit on the values, compute trig decomposition.
    Args:
        values: ndarray of points in the range [0, period]
        period: period of the data
    Returns:
        Decomposition of values into sine and cosine of data with given period
    """

    return np.sin(values * 2 * np.pi / period), np.cos(values * 2 * np.pi / period)


def trigonometric_datetime_transformation(datetimes: npt.ArrayLike) -> np.ndarray:
    """
    Given an iterable of datetimes, returns a trigonometric decomposition on hour, day and month
    Args:
        datetimes: ArrayLike of datetime64 values
    Returns:
        Trigonometric decomposition of datetime into hourly, daily and
        monthly values.
    """
    assert is_datetime64_dtype(datetimes), "Data for Trig Decomposition must be np.datetime64 type"

    datetimes = pd.DatetimeIndex(datetimes)
    hour = datetimes.hour.values.reshape(-1, 1) + (datetimes.minute.values.reshape(-1, 1) / 60)
    day = datetimes.day.values.reshape(-1, 1)
    month = datetimes.month.values.reshape(-1, 1)

    sine_hour, cosine_hour = _trig_transform(hour, 24)
    sine_day, cosine_day = _trig_transform(day, 366)
    sine_month, cosine_month = _trig_transform(month, 12)

    return np.concatenate(
        [sine_month, cosine_month, sine_day, cosine_day, sine_hour, cosine_hour], axis=1
    )

# %%
from xgboost import XGBRegressor
from xgboost import plot_importance
from sklearn.metrics import mean_squared_error, mean_absolute_error
import time
from dataclasses import dataclass

TRIG_DATETIME_FEATURE_NAMES = ["SIN_MONTH", "COS_MONTH", "SIN_DAY", "COS_DAY", "SIN_HOUR", "COS_HOUR"]


# optimal hyperparameters from prev trained model

hyperparams = {'objective': 'reg:squarederror',
               'base_score': 0.5,
               'booster': 'gbtree',
               'callbacks': None,
               'colsample_bylevel': 1,
               'colsample_bynode': 1,
               'colsample_bytree': 0.85,
               'early_stopping_rounds': None,
               'enable_categorical': False,
               'eval_metric': None,
               'feature_types': None,
               'gamma': 0,
               'gpu_id': -1,
               'grow_policy': 'depthwise',
               'importance_type': None,
               'interaction_constraints': '',
               'learning_rate': 0.01,
               'max_bin': 256,
               'max_cat_threshold': 64,
               'max_cat_to_onehot': 4,
               'max_delta_step': 0,
               'max_depth': 50,
               'max_leaves': 0,
               'min_child_weight': 20,
               'monotone_constraints': '()',
               'n_estimators': 1500,
               'n_jobs': -1,
               'num_parallel_tree': 1,
               'predictor': 'auto',
               'random_state': 0,
               'reg_alpha': 0,
               'reg_lambda': 1,
               'sampling_method': 'uniform',
               'scale_pos_weight': 1,
               'subsample': 0.85,
               'tree_method': 'hist',
               'validate_parameters': 1,
               'verbosity': 0
 }


@dataclass
class ExperimentSummary:
    look_ahead_hours: int
    mse_train_loss: float
    mse_test_loss: float
    mae_train_loss: float
    mae_test_loss: float
    feature_importance: pd.DataFrame
    


def run_experiment(forecast_horizon_hours: int):
    _start = time.time()
    X, target = build_datasets_for_prediction_horizon(forecast_horizon_hours)
    design = pd.DataFrame(data=X, columns=list(nwp.coords["variable"].values) + TRIG_DATETIME_FEATURE_NAMES)
    y = pd.DataFrame(data=target.values, columns=["GSP_PV"])
    
    # start with a randomised train/test split before structing a time-series specific one
    n = design.shape[0]
    train_idx = np.random.choice(np.arange(n), int(0.8*n), replace=False)
    test_idx = list(set(np.arange(n)).difference(train_idx))
    X_train, y_train = design.iloc[train_idx], y.iloc[train_idx]
    X_test, y_test = design.iloc[test_idx], y.iloc[test_idx]
    
    # fit a vanilla xgboost with basic hyperparameters
    model_xg = XGBRegressor(**hyperparams)
    model_xg.fit(X_train, y_train)
    
    mse_train, mse_test = mean_squared_error(y_train, model_xg.predict(X_train)), mean_squared_error(y_test, model_xg.predict(X_test))
    mae_train, mae_test = mean_absolute_error(y_train, model_xg.predict(X_train)), mean_absolute_error(y_test, model_xg.predict(X_test))
    
    feature_importances = pd.DataFrame.from_dict(model_xg.get_booster().get_score(importance_type='weight'), orient="index").sort_values(by=0, ascending=False)
    
    _end = time.time()
    
    print(f"Completed run for horizon: {forecast_horizon_hours} in {(_end - _start):.2f} seconds.")
    
    output = ExperimentSummary(
        forecast_horizon_hours,
        mse_train,
        mse_test,
        mae_train,
        mae_test,
        feature_importances
    )
    
    return output

# %%
results = run_experiment(4)
# Out:
# Completed run for horizon: 4 in 614.98 seconds.

# %%
results
# Out:
# ExperimentSummary(look_ahead_hours=4, mse_train_loss=948.1425050505437, mse_test_loss=32671.86007762036, mae_train_loss=14.74276017915931, mae_test_loss=94.72208444277068, feature_importance=                  0
# dswrf      108707.0
# wdir10      66760.0
# r           64723.0
# hcct        64404.0
# cdcb        63139.0
# si10        63085.0
# prate       62205.0
# hcc         62074.0
# lcc         59685.0
# prmsl       58326.0
# mcc         57490.0
# vis         57486.0
# SIN_HOUR    54970.0
# dlwrf       45333.0
# t           45106.0
# COS_HOUR    43800.0
# h           43530.0
# sde         39931.0
# SIN_DAY     39104.0
# dpt         33571.0
# COS_MONTH   15089.0
# SIN_MONTH    7273.0
# COS_DAY      5310.0)

# %%
import multiprocessing as mp

FORECAST_PERIODS = [2, 6, 12, 24, 36]

def driver_func():
    PROCESSES = 11
    with mp.Pool(PROCESSES) as pool:
        results = pool.imap_unordered(run_experiment, FORECAST_PERIODS)
    return results
        
output = driver_func()

# %%
PROCESSES = 11
with mp.Pool(PROCESSES) as pool:
    results = pool.imap(run_experiment, FORECAST_PERIODS)

# %%
results

# %%
import time
FORECAST_PERIODS = [2, 6, 12, 24, 36]
results = dict()

for lookahead in FORECAST_PERIODS:
    _start = time.time()
    results[lookahead] = run_experiment(lookahead)
    _end = time.time()
    print(f"Completed experiment for horizon: {lookahead}, took {(_end - _start):.2f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [120], line 7
#       5 for lookahead in FORECAST_PERIODS:
#       6     _start = time.time()
# ----> 7     results[lookahead] = run_experiment(lookahead)
#       8     _end = time.time()
#       9     print(f"Completed experiment for horizon: {lookahead}, took {(_end - _start):.2f}")
#
# Cell In [119], line 66, in run_experiment(forecast_horizon_hours)
#      65 def run_experiment(forecast_horizon_hours: int):
# ---> 66     X, target = build_datasets_for_prediction_horizon(forecast_horizon_hours)
#      67     design = pd.DataFrame(data=X, columns=list(nwp.coords["variable"].values) + TRIG_DATETIME_FEATURE_NAMES)
#      68     y = pd.DataFrame(data=target.values, columns=["GSP_PV"])
#
# Cell In [61], line 17, in build_datasets_for_prediction_horizon(hour_forecast_horizon)
#      14 X = X.interp(init_time=new_times, method="cubic")
#      16 # compute the transformation - this can take some time
# ---> 17 _X = X.to_array().as_numpy()
#      18 _X = _X.values.reshape(_X.shape[1], _X.shape[2]).T
#      20 # compute datetime features
#
# File ~/mambaforge/envs/xg_pv/lib/python3.10/site-packages/xarray/core/dataarray.py:759, in DataArray.as_numpy(self)
#     748 """
#     749 Coerces wrapped data and coordinates into numpy arrays, returning a DataArray.
#     750
#    (...)
#     756 DataArray.data
#     757 """
#     758 coords = {k: v.as_numpy() for k, v in self._coords.items()}
# --> 759 return self._replace(self.variable.as_numpy(), coords, indexes=self._indexes)
#
# File ~/mambaforge/envs/xg_pv/lib/python3.10/site-packages/xarray/core/variable.py:1257, in Variable.as_numpy(self)
#    1255 def as_numpy(self: T_Variable) -> T_Variable:
#    1256     """Coerces wrapped data into a numpy array, returning a Variable."""
# -> 1257     return self._replace(data=self.to_numpy())
#
# File ~/mambaforge/envs/xg_pv/lib/python3.10/site-packages/xarray/core/variable.py:1243, in Variable.to_numpy(self)
#    1241 # TODO first attempt to call .to_numpy() once some libraries implement it
#    1242 if hasattr(data, "chunks"):
# -> 1243     data = data.compute()
#    1244 if isinstance(data, array_type("cupy")):
#    1245     data = data.get()
#
# File ~/mambaforge/envs/xg_pv/lib/python3.10/site-packages/dask/base.py:315, in DaskMethodsMixin.compute(self, **kwargs)
#     291 def compute(self, **kwargs):
#     292     """Compute this dask collection
#     293
#     294     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     313     dask.base.compute
#     314     """
# --> 315     (result,) = compute(self, traverse=False, **kwargs)
#     316     return result
#
# File ~/mambaforge/envs/xg_pv/lib/python3.10/site-packages/dask/base.py:600, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     597     keys.append(x.__dask_keys__())
#     598     postcomputes.append(x.__dask_postcompute__())
# --> 600 results = schedule(dsk, keys, **kwargs)
#     601 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/mambaforge/envs/xg_pv/lib/python3.10/site-packages/dask/threaded.py:89, in get(dsk, keys, cache, num_workers, pool, **kwargs)
#      86     elif isinstance(pool, multiprocessing.pool.Pool):
#      87         pool = MultiprocessingPoolExecutor(pool)
# ---> 89 results = get_async(
#      90     pool.submit,
#      91     pool._max_workers,
#      92     dsk,
#      93     keys,
#      94     cache=cache,
#      95     get_id=_thread_get_id,
#      96     pack_exception=pack_exception,
#      97     **kwargs,
#      98 )
#     100 # Cleanup pools associated to dead threads
#     101 with pools_lock:
#
# File ~/mambaforge/envs/xg_pv/lib/python3.10/site-packages/dask/local.py:500, in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     498 while state["waiting"] or state["ready"] or state["running"]:
#     499     fire_tasks(chunksize)
# --> 500     for key, res_info, failed in queue_get(queue).result():
#     501         if failed:
#     502             exc, tb = loads(res_info)
#
# File ~/mambaforge/envs/xg_pv/lib/python3.10/site-packages/dask/local.py:137, in queue_get(q)
#     136 def queue_get(q):
# --> 137     return q.get()
#
# File ~/mambaforge/envs/xg_pv/lib/python3.10/queue.py:171, in Queue.get(self, block, timeout)
#     169 elif timeout is None:
#     170     while not self._qsize():
# --> 171         self.not_empty.wait()
#     172 elif timeout < 0:
#     173     raise ValueError("'timeout' must be a non-negative number")
#
# File ~/mambaforge/envs/xg_pv/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
t.shape
# Out:
# (32527,)

# %%
TRIG_DATETIME_FEATURE_NAMES = ["SIN_MONTH", "COS_MONTH", "SIN_DAY", "COS_DAY", "SIN_HOUR", "COS_HOUR"]

design = pd.DataFrame(data=X, columns=list(nwp.coords["variable"].values) + TRIG_DATETIME_FEATURE_NAMES)
y = pd.DataFrame(data=t.values, columns=["GSP_PV"])

# %%
design
# Out:
#               cdcb        lcc        mcc        hcc       sde          hcct  \
# 0       741.037415  72.042336   5.844196  34.085106  0.001284 -32629.847656
# 1       846.115728  71.512390   6.510461  34.468965  0.001284 -32629.815620
# 2       930.178850  71.279814   7.061962  35.162847  0.001283 -32629.801058
# 3       995.758329  71.296329   7.524143  36.108798  0.001283 -32629.800476
# 4      1045.385715  71.513656   7.922447  37.248863  0.001283 -32629.810378
# ...            ...        ...        ...        ...       ...           ...
# 32522  1342.216489  65.697899  55.748757  55.647372  0.000025 -32629.872598
# 32523  1298.912216  65.945533  56.355288  54.918672  0.000025 -32629.879224
# 32524  1265.719572  65.991533  56.780552  53.725912  0.000025 -32629.878834
# 32525  1246.916486  65.778100  56.956807  51.999972  0.000025 -32629.869091
# 32526  1246.780884  65.247437  56.816315  49.671730  0.000025 -32629.847656
#
#            dswrf       dlwrf            h           t  ...      si10  \
# 0       0.000000  317.419373  2677.870117  280.206604  ...  6.927804
# 1       3.041823  317.230297  2689.133955  280.210169  ...  6.910879
# 2       4.424470  317.302667  2694.594681  280.208754  ...  6.904457
# 3       4.479776  317.595051  2695.072024  280.203625  ...  6.907043
# 4       3.539576  318.066020  2691.385711  280.196045  ...  6.917145
# ...          ...         ...          ...         ...  ...       ...
# 32522  80.769778  348.261549  3116.184541  284.951399  ...  7.150144
# 32523  65.305598  348.718918  3108.364098  284.974187  ...  7.205964
# 32524  48.154679  348.869308  3095.987756  284.953531  ...  7.237817
# 32525  29.659316  348.649210  3078.589818  284.884549  ...  7.241345
# 32526  10.161805  347.995117  3055.704590  284.762360  ...  7.212185
#
#            wdir10          prmsl     prate  SIN_MONTH  COS_MONTH   SIN_DAY  \
# 0      189.318909  102674.898438  0.000001        0.5   0.866025  0.017166
# 1      188.798340  102653.732780  0.000001        0.5   0.866025  0.017166
# 2      188.808906  102631.675947  0.000002        0.5   0.866025  0.017166
# 3      189.260508  102609.180393  0.000002        0.5   0.866025  0.017166
# 4      190.063048  102586.698570  0.000002        0.5   0.866025  0.017166
# ...           ...            ...       ...        ...        ...       ...
# 32522  224.342014  101615.538653  0.000055       -0.5   0.866025  0.136906
# 32523  224.791900  101597.828705  0.000056       -0.5   0.866025  0.136906
# 32524  224.745490  101585.341719  0.000057       -0.5   0.866025  0.136906
# 32525  224.089356  101579.424005  0.000060       -0.5   0.866025  0.136906
# 32526  222.710068  101581.421875  0.000064       -0.5   0.866025  0.136906
#
#         COS_DAY  SIN_HOUR  COS_HOUR
# 0      0.999853  0.000000  1.000000
# 1      0.999853  0.130526  0.991445
# 2      0.999853  0.258819  0.965926
# 3      0.999853  0.382683  0.923880
# 4      0.999853  0.500000  0.866025
# ...         ...       ...       ...
# 32522  0.990584 -0.258819 -0.965926
# 32523  0.990584 -0.382683 -0.923880
# 32524  0.990584 -0.500000 -0.866025
# 32525  0.990584 -0.608761 -0.793353
# 32526  0.990584 -0.707107 -0.707107
#
# [32527 rows x 23 columns]

# %%
# start with a randomised train/test split before structing a time-series specific one
n = design.shape[0]
train_idx = np.random.choice(np.arange(n), int(0.8*n), replace=False)
test_idx = list(set(np.arange(n)).difference(train_idx))
X_train, y_train = design.iloc[train_idx], y.iloc[train_idx]
X_test, y_test = design.iloc[test_idx], y.iloc[test_idx]

# %%
# optimal hyperparameters from prev trained model

hyperparams = {'objective': 'reg:squarederror',
               'base_score': 0.5,
               'booster': 'gbtree',
               'callbacks': None,
               'colsample_bylevel': 1,
               'colsample_bynode': 1,
               'colsample_bytree': 0.85,
               'early_stopping_rounds': None,
               'enable_categorical': False,
               'eval_metric': None,
               'feature_types': None,
               'gamma': 0,
               'gpu_id': -1,
               'grow_policy': 'depthwise',
               'importance_type': None,
               'interaction_constraints': '',
               'learning_rate': 0.01,
               'max_bin': 256,
               'max_cat_threshold': 64,
               'max_cat_to_onehot': 4,
               'max_delta_step': 0,
               'max_depth': 50,
               'max_leaves': 0,
               'min_child_weight': 20,
               'monotone_constraints': '()',
               'n_estimators': 1500,
               'n_jobs': -1,
               'num_parallel_tree': 1,
               'predictor': 'auto',
               'random_state': 0,
               'reg_alpha': 0,
               'reg_lambda': 1,
               'sampling_method': 'uniform',
               'scale_pos_weight': 1,
               'subsample': 0.85,
               'tree_method': 'exact',
               'validate_parameters': 1,
               'verbosity': 
 }

# %%
plt.bar(range(len(model_xg.feature_importances_)), model_xg.feature_importances_)
# Out:
# <BarContainer object of 23 artists>

# %%
pd.DataFrame.from_dict(model_xg.get_booster().get_score(importance_type='gain'), orient="index").sort_values(by=0, ascending=False)
# Out:
#                       0
# dswrf      4.196247e+07
# COS_MONTH  1.594917e+07
# COS_HOUR   1.584646e+07
# prate      3.160394e+06
# SIN_HOUR   2.739078e+06
# sde        2.313869e+06
# lcc        1.672848e+06
# SIN_MONTH  1.308780e+06
# vis        9.440874e+05
# r          8.318919e+05
# t          8.311739e+05
# prmsl      6.790955e+05
# wdir10     6.509894e+05
# hcct       6.475383e+05
# COS_DAY    6.302464e+05
# SIN_DAY    6.293394e+05
# cdcb       5.973009e+05
# dlwrf      5.940710e+05
# mcc        5.249634e+05
# h          4.951346e+05
# si10       4.661888e+05
# hcc        4.286439e+05
# dpt        4.271299e+05

# %%
sorted_idx = model_xg.feature_importances_.argsort()
plt.barh(design.columns[sorted_idx], model_xg.feature_importances_[sorted_idx])
plt.xlabel("Xgboost Feature Importance")
# Out:
# Text(0.5, 0, 'Xgboost Feature Importance')

# %%
plot_importance(model_xg, importance_type="weight")
# Out:
# <AxesSubplot: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
from xgboost import XGBRegressor
from xgboost import plot_importance
from sklearn.metrics import mean_squared_error

# fit a vanilla xgboost with basic hyperparameters
model_xg = XGBRegressor(**hyperparams)
model_xg.fit(X_train, y_train)
# Out:
# [12:51:45] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 698 extra nodes, 0 pruned nodes, max_depth=14
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 618 extra nodes, 0 pruned nodes, max_depth=19
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 630 extra nodes, 0 pruned nodes, max_depth=22
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 808 extra nodes, 0 pruned nodes, max_depth=19
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 688 extra nodes, 0 pruned nodes, max_depth=26
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 658 extra nodes, 0 pruned nodes, max_depth=23
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 814 extra nodes, 0 pruned nodes, max_depth=19
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 688 extra nodes, 0 pruned nodes, max_depth=24
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 870 extra nodes, 0 pruned nodes, max_depth=20
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 702 extra nodes, 0 pruned nodes, max_depth=25
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 708 extra nodes, 0 pruned nodes, max_depth=28
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 740 extra nodes, 0 pruned nodes, max_depth=25
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 732 extra nodes, 0 pruned nodes, max_depth=31
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 762 extra nodes, 0 pruned nodes, max_depth=29
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 716 extra nodes, 0 pruned nodes, max_depth=27
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 712 extra nodes, 0 pruned nodes, max_depth=26
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 724 extra nodes, 0 pruned nodes, max_depth=25
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 812 extra nodes, 0 pruned nodes, max_depth=32
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1438 extra nodes, 0 pruned nodes, max_depth=23
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1304 extra nodes, 0 pruned nodes, max_depth=33
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1230 extra nodes, 0 pruned nodes, max_depth=36
# [12:51:46] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1250 extra nodes, 0 pruned nodes, max_depth=31
# [12:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1356 extra nodes, 0 pruned nodes, max_depth=30
# [12:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1266 extra nodes, 0 pruned nodes, max_depth=34
# [12:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1292 extra nodes, 0 pruned nodes, max_depth=33
# [12:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1328 extra nodes, 0 pruned nodes, max_depth=35
# [12:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1462 extra nodes, 0 pruned nodes, max_depth=35
# [12:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1426 extra nodes, 0 pruned nodes, max_depth=32
# [12:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1282 extra nodes, 0 pruned nodes, max_depth=40
# [12:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1356 extra nodes, 0 pruned nodes, max_depth=34
# [12:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1316 extra nodes, 0 pruned nodes, max_depth=37
# [12:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1382 extra nodes, 0 pruned nodes, max_depth=36
# [12:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1342 extra nodes, 0 pruned nodes, max_depth=36
# [12:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1348 extra nodes, 0 pruned nodes, max_depth=32
# [12:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1380 extra nodes, 0 pruned nodes, max_depth=38
# [12:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1378 extra nodes, 0 pruned nodes, max_depth=39
# [12:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1382 extra nodes, 0 pruned nodes, max_depth=33
# [12:51:47] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1360 extra nodes, 0 pruned nodes, max_depth=39
# [12:51:48] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1394 extra nodes, 0 pruned nodes, max_depth=36
# [12:51:48] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1362 extra nodes, 0 pruned nodes, max_depth=40
# [12:51:48] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1434 extra nodes, 0 pruned nodes, max_depth=39
# [12:51:48] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1396 extra nodes, 0 pruned nodes, max_depth=41
# [12:51:48] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1434 extra nodes, 0 pruned nodes, max_depth=38
# [12:51:48] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1394 extra nodes, 0 pruned nodes, max_depth=36
# [12:51:48] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1410 extra nodes, 0 pruned nodes, max_depth=40
# [12:51:48] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1486 extra nodes, 0 pruned nodes, max_depth=30
# [12:51:48] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1418 extra nodes, 0 pruned nodes, max_depth=36
# [12:51:48] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1506 extra nodes, 0 pruned nodes, max_depth=40
# [12:51:48] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1408 extra nodes, 0 pruned nodes, max_depth=35
# [12:51:48] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1444 extra nodes, 0 pruned nodes, max_depth=38
# [12:51:48] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1438 extra nodes, 0 pruned nodes, max_depth=41
# [12:51:48] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1488 extra nodes, 0 pruned nodes, max_depth=36
# [12:51:48] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1450 extra nodes, 0 pruned nodes, max_depth=39
# [12:51:48] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1414 extra nodes, 0 pruned nodes, max_depth=38
# [12:51:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1446 extra nodes, 0 pruned nodes, max_depth=39
# [12:51:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1474 extra nodes, 0 pruned nodes, max_depth=41
# [12:51:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1454 extra nodes, 0 pruned nodes, max_depth=37
# [12:51:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1464 extra nodes, 0 pruned nodes, max_depth=41
# [12:51:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1492 extra nodes, 0 pruned nodes, max_depth=40
# [12:51:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1520 extra nodes, 0 pruned nodes, max_depth=33
# [12:51:49] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 
INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1682 extra nodes, 0 pruned nodes, max_depth=38
# [12:51:59] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1698 extra nodes, 0 pruned nodes, max_depth=36
# [12:51:59] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1674 extra nodes, 0 pruned nodes, max_depth=45
# [12:51:59] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1718 extra nodes, 0 pruned nodes, max_depth=46
# [12:52:00] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1696 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:00] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1688 extra nodes, 0 pruned nodes, max_depth=47
# [12:52:00] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1682 extra nodes, 0 pruned nodes, max_depth=47
# [12:52:00] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1690 extra nodes, 0 pruned nodes, max_depth=47
# [12:52:00] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1704 extra nodes, 0 pruned nodes, max_depth=47
# [12:52:00] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1678 extra nodes, 0 pruned nodes, max_depth=40
# [12:52:00] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1706 extra nodes, 0 pruned nodes, max_depth=39
# [12:52:00] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1700 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:00] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1690 extra nodes, 0 pruned nodes, max_depth=42
# [12:52:00] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1684 extra nodes, 0 pruned nodes, max_depth=42
# [12:52:00] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1648 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:00] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1676 extra nodes, 0 pruned nodes, max_depth=46
# [12:52:01] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1698 extra nodes, 0 pruned nodes, max_depth=42
# [12:52:01] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1694 extra nodes, 0 pruned nodes, max_depth=45
# [12:52:01] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1672 extra nodes, 0 pruned nodes, max_depth=48
# [12:52:01] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1680 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:01] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1708 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:01] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1694 extra nodes, 0 pruned nodes, max_depth=40
# [12:52:01] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1712 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:01] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1690 extra nodes, 0 pruned nodes, max_depth=47
# [12:52:01] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1664 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:01] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1668 extra nodes, 0 pruned nodes, max_depth=49
# [12:52:02] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1706 extra nodes, 0 pruned nodes, max_depth=47
# [12:52:02] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1664 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:02] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1700 extra nodes, 0 pruned nodes, max_depth=40
# [12:52:02] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1708 extra nodes, 0 pruned nodes, max_depth=38
# [12:52:02] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1700 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:02] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1692 extra nodes, 0 pruned nodes, max_depth=49
# [12:52:03] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1700 extra nodes, 0 pruned nodes, max_depth=42
# [12:52:03] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1702 extra nodes, 0 pruned nodes, max_depth=38
# [12:52:03] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1708 extra nodes, 0 pruned nodes, max_depth=44
# [12:52:03] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1714 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:03] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1704 extra nodes, 0 pruned nodes, max_depth=48
# [12:52:03] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1714 extra nodes, 0 pruned nodes, max_depth=39
# [12:52:03] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1692 extra nodes, 0 pruned nodes, max_depth=44
# [12:52:03] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1676 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:03] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1712 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:03] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1692 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:03] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1682 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:04] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1686 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:04] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1716 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:04] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1698 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:04] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1696 extra nodes, 0 pruned nodes, max_depth=47
# [12:52:04] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1738 extra nodes, 0 pruned nodes, max_depth=28
# [12:52:04] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1710 extra nodes, 0 pruned nodes, max_depth=49
# [12:52:04] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1704 extra nodes, 0 pruned nodes, max_depth=49
# [12:52:04] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1686 extra nodes, 0 pruned nodes, max_depth=41
# [12:52:04] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1648 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:04] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1696 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:04] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1670 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:04] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1710 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:05] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1710 extra nodes, 0 pruned nodes, max_depth=49
# [12:52:05] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1692 extra nodes, 0 pruned nodes, max_depth=49
# [12:52:05] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1692 extra nodes, 0 pruned nodes, max_depth=43
# [12:52:05] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1684 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:05] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1696 extra nodes, 0 pruned nodes, max_depth=49
# [12:52:05] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1722 extra nodes, 0 pruned nodes, max_depth=48
# [12:52:05] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1712 extra nodes, 0 pruned nodes, max_depth=50
# [12:52:05] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1706 extra nodes, 0 pruned nodes, max_depth=50
# ...
# [12:54:25] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 884 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:25] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 802 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:25] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1530 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:25] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 468 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:25] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 644 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:26] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1516 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:26] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 928 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:26] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1558 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:26] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 580 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:26] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 576 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:26] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 612 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:26] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 720 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:27] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1548 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:27] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1056 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:27] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 562 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:27] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 578 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:27] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 552 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:27] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 664 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:27] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1134 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:28] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 514 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:28] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 886 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:28] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 398 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:28] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 282 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:28] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1164 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:28] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 700 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:29] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1030 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:29] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1598 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:29] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1182 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:29] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 514 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:29] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 716 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:29] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1016 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:29] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 262 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 964 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 442 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 562 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1400 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 908 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1070 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:30] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 290 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1054 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 418 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 664 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 534 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 952 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 438 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 734 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:31] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1414 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:32] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1696 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:32] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1416 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:32] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 362 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:32] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 902 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:32] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 474 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:32] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1294 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:32] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 940 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:32] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1578 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:33] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 886 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:33] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 606 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:33] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1130 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:33] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 796 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:33] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 652 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:33] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 504 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:33] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 364 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:33] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 638 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 698 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 744 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 460 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1112 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 456 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:34] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 364 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:35] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 618 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:35] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 432 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:35] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 348 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:35] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1180 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:35] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 592 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:35] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 708 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:35] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1368 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:36] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 448 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:36] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 666 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:36] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 760 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:36] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1084 extra nodes, 0 pruned nodes, max_depth=50
# [12:54:36] INFO: /home/conda/feedstock_root/build_artifacts/xgboost-split_1667849527992/work/src/tree/updater_prune.cc:98: tree pruning end, 1044 extra nodes, 0 pruned nodes, max_depth=50
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.85,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.01, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=50, max_leaves=0, min_child_weight=20, missing=nan,
#              monotone_constraints='()', n_estimators=1500, n_jobs=-1,
#              num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
print(f"MSE (training/testing): {mean_squared_error(y_train, model_xg.predict(X_train)):.3f}/{mean_squared_error(y_test, model_xg.predict(X_test)):.3f}")
# Out:
# MSE (training/testing): 1146.044/39656.146
